# %%
import os

from pyspark.sql import SparkSession
from pyspark.sql.functions import input_file_name

INBOX_DIR = "data/inbox"

spark = SparkSession.builder.appName("Project1").getOrCreate()


def list_parquet_files(inbox_dir: str):
    if not os.path.isdir(inbox_dir):
        return []

    return sorted(
        os.path.join(inbox_dir, name)
        for name in os.listdir(inbox_dir)
        if name.endswith(".parquet")
    )


parquet_files = list_parquet_files(INBOX_DIR)
print(f"Parquet files to read: {len(parquet_files)}")
if parquet_files:
    df = spark.read.parquet(*parquet_files).withColumn(
        "source_file", input_file_name()
    )
else:
    df = None
    print("No parquet files found; skipping.")
# Out:
# Parquet files to read: 0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 24
#      22 parquet_files = list_parquet_files(INBOX_DIR)
#      23 print(f"Parquet files to read: {len(parquet_files)}")
# ---> 24 df;
#      25 if parquet_files:
#      26     df = spark.read.parquet(*parquet_files).withColumn(
#      27         "source_file", input_file_name()
#      28     )
#
# NameError: name 'df' is not defined

# %%
df.show(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.show(3)
#
# NameError: name 'df' is not defined
